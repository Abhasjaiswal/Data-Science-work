# %%
import pandas as pd 
import numpy as np

# %%
df1=pd.read_csv("Reactions.csv",parse_dates=['Datetime'])
df2=pd.read_csv("ReactionTypes.csv")
df3=pd.read_csv("Content.csv")

# %%
df1
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 0                                       NaN         NaN 2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# ...

# %%
df1.dtypes
# Out:
# Unnamed: 0             int64
# Content ID            object
# User ID               object
# Type                  object
# Datetime      datetime64[ns]
# dtype: object

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Content ID', 'User ID', 'Type', 'Datetime'], dtype='object')

# %%
df1.drop('Unnamed: 0', axis=1,inplace=True)

# %%
df1
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 0                                       NaN         NaN 2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# ...

# %%
df2
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
df3
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
df3.drop(columns=['URL','Unnamed: 0'], axis=1,inplace=True)

# %%
df3
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# ...

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3.isnull().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Category      0
# dtype: int64

# %%
df3['Type'].unique()
# Out:
# array(['photo', 'video', 'GIF', 'audio'], dtype=object)

# %%
df3.columns
# Out:
# Index(['Content ID', 'User ID', 'Type', 'Category'], dtype='object')

# %%
df3['Category'].unique()
# Out:
# array(['Studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'studying', 'veganism', 'Animals',
#        'animals', 'culture', '"culture"', 'Fitness', '"studying"',
#        'Veganism', '"animals"', 'Travel', '"soccer"', 'Education',
#        '"dogs"', 'Technology', 'Soccer', '"tennis"', 'Culture', '"food"',
#        'Food', '"technology"', 'Healthy Eating', '"cooking"', 'Science',
#        '"public speaking"', '"veganism"', 'Public Speaking', '"science"'],
#       dtype=object)

# %%
df3['Category'] = df3['Category'].str.strip('"').str.title()

# %%
df3
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   Healthy Eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   Healthy Eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       Technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             Food
# ...

# %%
df3['Category'].unique()
# Out:
# array(['Studying', 'Healthy Eating', 'Technology', 'Food', 'Cooking',
#        'Dogs', 'Soccer', 'Public Speaking', 'Science', 'Tennis', 'Travel',
#        'Fitness', 'Education', 'Veganism', 'Animals', 'Culture'],
#       dtype=object)

# %%
df3.shape
# Out:
# (1000, 4)

# %%
df3.isnull().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Category      0
# dtype: int64

# %%
df3.isna().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Category      0
# dtype: int64

# %%
df3
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   Healthy Eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   Healthy Eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       Technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             Food
# ...

# %%
df2
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
df2.drop('Unnamed: 0', axis=1,inplace=True)

# %%
df2
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
df1
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 0                                       NaN         NaN 2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# ...

# %%
df1
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 0                                       NaN         NaN 2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# ...

# %%
df1.isnull().sum()
# Out:
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
df1
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 0                                       NaN         NaN 2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# ...

# %%
df1 = df1.dropna(subset=['Type'])

# %%
df1
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust 2021-01-06 19:13:01
# ...

# %%
df2
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
df1
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust 2021-01-06 19:13:01
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df1
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust 2021-01-06 19:13:01
# ...

# %%
df2
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
df3
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   Healthy Eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   Healthy Eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       Technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             Food
# ...

# %%
df3['Category'].unique()
# Out:
# array(['Studying', 'Healthy Eating', 'Technology', 'Food', 'Cooking',
#        'Dogs', 'Soccer', 'Public Speaking', 'Science', 'Tennis', 'Travel',
#        'Fitness', 'Education', 'Veganism', 'Animals', 'Culture'],
#       dtype=object)

# %%
df3
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   Healthy Eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   Healthy Eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       Technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             Food
# ...

# %%
df1.columns
# Out:
# Index(['Content ID', 'User ID', 'Type', 'Datetime'], dtype='object')

# %%
df1.drop(['User ID'],axis=1,inplace=True)
# Out:
# /var/folders/zp/n6ct9bzs28q19545cxvx7zv00000gn/T/ipykernel_42344/494236529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(['User ID'],axis=1,inplace=True)

# %%
df1
# Out:
#                                  Content ID        Type            Datetime
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust 2020-11-07 09:43:50
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike 2021-06-17 12:22:51
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2      scared 2021-04-18 05:13:58
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust 2021-01-06 19:13:01
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2  interested 2020-08-23 12:25:58
# ...                                     ...         ...                 ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike 2020-06-27 09:46:48
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued 2021-02-16 17:17:02
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56  interested 2020-09-12 03:54:58
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried 2020-11-04 20:08:31
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish 2021-01-04 04:55:11
#
# [24573 rows x 3 columns]

# %%
df1.dtypes
# Out:
# Content ID            object
# Type                  object
# Datetime      datetime64[ns]
# dtype: object

# %%
df3.columns
# Out:
# Index(['Content ID', 'User ID', 'Type', 'Category'], dtype='object')

# %%
df3.drop(['User ID'],axis=1,inplace=True)

# %%
df3
# Out:
#                                Content ID   Type         Category
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2  photo         Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo   Healthy Eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f  photo   Healthy Eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6  photo       Technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180  video             Food
# ..                                    ...    ...              ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb  video  Public Speaking
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c    GIF       Technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b  audio         Veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    GIF          Culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56  audio       Technology
#
# [1000 rows x 3 columns]

# %%
df1.columns
# Out:
# Index(['Content ID', 'Type', 'Datetime'], dtype='object')

# %%
df1.rename(columns={'Type':'Reaction Type'},inplace=True)
# Out:
# /var/folders/zp/n6ct9bzs28q19545cxvx7zv00000gn/T/ipykernel_42344/889763226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={'Type':'Reaction Type'},inplace=True)

# %%
df1
# Out:
#                                  Content ID Reaction Type            Datetime
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2020-11-07 09:43:50
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike 2021-06-17 12:22:51
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared 2021-04-18 05:13:58
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2021-01-06 19:13:01
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested 2020-08-23 12:25:58
# ...                                     ...           ...                 ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike 2020-06-27 09:46:48
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued 2021-02-16 17:17:02
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56    interested 2020-09-12 03:54:58
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried 2020-11-04 20:08:31
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish 2021-01-04 04:55:11
#
# [24573 rows x 3 columns]

# %%
df1.isnull().sum()
# Out:
# Content ID       0
# Reaction Type    0
# Datetime         0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Type', 'Sentiment', 'Score'], dtype='object')

# %%
df3.columns
# Out:
# Index(['Content ID', 'Type', 'Category'], dtype='object')

# %%
df1.columns
# Out:
# Index(['Content ID', 'Reaction Type', 'Datetime'], dtype='object')

# %%
df3.columns
# Out:
# Index(['Content ID', 'Type', 'Category'], dtype='object')

# %%
df2.rename(columns={'Type':'Reaction Type'},inplace=True)

# %%
df2
# Out:
#    Reaction Type Sentiment  Score
# 0          heart  positive     60
# 1           want  positive     70
# 2        disgust  negative      0
# 3           hate  negative      5
# 4     interested  positive     30
# 5    indifferent   neutral     20
# 6           love  positive     65
# 7     super love  positive     75
# 8        cherish  positive     70
# 9          adore  positive     72
# 10          like  positive     50
# 11       dislike  negative     10
# 12     intrigued  positive     45
# 13       peeking   neutral     35
# 14        scared  negative     15
# 15       worried  negative     12

# %%
df2.columns
# Out:
# Index(['Reaction Type', 'Sentiment', 'Score'], dtype='object')

# %%
merged_df = pd.merge(df1, df3, how='inner', on='Content ID')

# %%
merged_df
# Out:
#                                  Content ID Reaction Type            Datetime  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2020-11-07 09:43:50
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike 2021-06-17 12:22:51
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared 2021-04-18 05:13:58
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2021-01-06 19:13:01
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested 2020-08-23 12:25:58
# ...                                     ...           ...                 ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike 2020-06-27 09:46:48
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued 2021-02-16 17:17:02
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested 2020-09-12 03:54:58
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried 2020-11-04 20:08:31
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish 2021-01-04 04:55:11
#
#         Type    Category
# ...

# %%
merged_df.columns
# Out:
# Index(['Content ID', 'Reaction Type', 'Datetime', 'Type', 'Category'], dtype='object')

# %%
merged_df
# Out:
#                                  Content ID Reaction Type            Datetime  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2020-11-07 09:43:50
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike 2021-06-17 12:22:51
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared 2021-04-18 05:13:58
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust 2021-01-06 19:13:01
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested 2020-08-23 12:25:58
# ...                                     ...           ...                 ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike 2020-06-27 09:46:48
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued 2021-02-16 17:17:02
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested 2020-09-12 03:54:58
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried 2020-11-04 20:08:31
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish 2021-01-04 04:55:11
#
#         Type    Category
# ...

# %%
df2.columns
# Out:
# Index(['Reaction Type', 'Sentiment', 'Score'], dtype='object')

# %%
df1=df1.to_csv('Cleaned_Reactions.csv', index=False)

# %%
df2=df2.to_csv('Cleaned_Reaction_type.csv', index=False)

# %%
df=df3.to_csv('cleaned_contents.csv', index=False)

# %%
result_df = pd.merge(merged_df, df2, how='inner', left_on='Reaction Type', right_on='Reaction Type',)
result_df

# %%
result_df=result_df.to_csv('final_merge.csv', index=False)

# %%
category_scores = result_df.groupby('Category')['Score'].sum().reset_index()
category_scores=category_scores.to_csv('category_scores.csv', index=False)

# %%
sorted_categories = category_scores.sort_values(by='Score', ascending=False)
sorted_categories = sorted_categories.to_csv('sorted_categories.csv', index=False)

# %%
top_5_categories = sorted_categories.head(5)
top_5_categories
# Out:
#           Category  Score
# 0          Animals  74965
# 9          Science  71168
# 7   Healthy Eating  69339
# 12      Technology  68738
# 6             Food  66676

# %%
top_5_categories.to_csv('top_5_categories.csv', index=False)
