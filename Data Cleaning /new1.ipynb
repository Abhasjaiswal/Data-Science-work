# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('new.csv')
df
# Out:
#        Name  Age  Gender Country  Salary
# 0      John   25    Male     USA   60000
# 1      Emma   32  Female  Canada   80000
# 2   Michael   45    Male      UK   90000
# 3    Sophia   27  Female     USA   70000
# 4   William   35    Male  Canada   75000
# 5    Olivia   29  Female      UK   82000
# 6     James   40    Male     USA   95000
# 7  Isabella   33  Female  Canada   78000

# %%
df.sort_values('Age',ascending=True)
# Out:
#        Name  Age  Gender Country  Salary
# 0      John   25    Male     USA   60000
# 3    Sophia   27  Female     USA   70000
# 5    Olivia   29  Female      UK   82000
# 1      Emma   32  Female  Canada   80000
# 7  Isabella   33  Female  Canada   78000
# 4   William   35    Male  Canada   75000
# 6     James   40    Male     USA   95000
# 2   Michael   45    Male      UK   90000

# %%
df.sort_values('Age',ascending=False)
# Out:
#        Name  Age  Gender Country  Salary
# 2   Michael   45    Male      UK   90000
# 6     James   40    Male     USA   95000
# 4   William   35    Male  Canada   75000
# 7  Isabella   33  Female  Canada   78000
# 1      Emma   32  Female  Canada   80000
# 5    Olivia   29  Female      UK   82000
# 3    Sophia   27  Female     USA   70000
# 0      John   25    Male     USA   60000

# %%
df.sort_values(['Age','Salary'],ascending=[True,False])
# Out:
#        Name  Age  Gender Country  Salary
# 0      John   25    Male     USA   60000
# 3    Sophia   27  Female     USA   70000
# 5    Olivia   29  Female      UK   82000
# 1      Emma   32  Female  Canada   80000
# 7  Isabella   33  Female  Canada   78000
# 4   William   35    Male  Canada   75000
# 6     James   40    Male     USA   95000
# 2   Michael   45    Male      UK   90000

# %%
df['Name']
# Out:
# 0        John
# 1        Emma
# 2     Michael
# 3      Sophia
# 4     William
# 5      Olivia
# 6       James
# 7    Isabella
# Name: Name, dtype: object

# %%
df[['Name','Age']]
# Out:
#        Name  Age
# 0      John   25
# 1      Emma   32
# 2   Michael   45
# 3    Sophia   27
# 4   William   35
# 5    Olivia   29
# 6     James   40
# 7  Isabella   33

# %%
df[df['Age']>40]
# Out:
#       Name  Age Gender Country  Salary
# 2  Michael   45   Male      UK   90000

# %%
df[df['Age']==25]
# Out:
#    Name  Age Gender Country  Salary
# 0  John   25   Male     USA   60000

# %%
df
# Out:
#        Name  Age  Gender Country  Salary
# 0      John   25    Male     USA   60000
# 1      Emma   32  Female  Canada   80000
# 2   Michael   45    Male      UK   90000
# 3    Sophia   27  Female     USA   70000
# 4   William   35    Male  Canada   75000
# 5    Olivia   29  Female      UK   82000
# 6     James   40    Male     USA   95000
# 7  Isabella   33  Female  Canada   78000

# %%
df[df[df]]
